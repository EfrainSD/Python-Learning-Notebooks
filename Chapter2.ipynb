# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrainSD/Python-Learning-Notebooks/blob/main/Chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 2: Variables, Expressions and Statements

# %% [markdown]
# Below we see the types of each of them and the importance of quotation marks.

# %%
type("3")
# Out:
# str

# %%
type(3)
# Out:
# int

# %% [markdown]
# <h1> The types are: </hi1>
#
# * Integers -> int
# * Floating point -> float
# * Strings -> str
# * Lists -> list
# * Dictionaries -> dict (Key:value pairs)
# * Tuples -> tup (Sequence of ordered immutable objects)
# * Sets -> set (Unordered collection of unique objects)
# * Booleans -> bool

# %% [markdown]
# <h1> Be careful with commas </h1>
# To indicate thousands, we write the number as it is: 10000.
# If we write 10,000 or 10.000, these are completely different values.

# %%
10,000
# Out:
# (10, 0)

# %%
10.000
# Out:
# 10.0

# %% [markdown]
# <h1> There are keywords that cannot be used for variables (KeyWord): </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1> Operators </h1>
#
# Apart from the usual ones, there are three important ones:
# * Exponential: **
# * Integer division: // (rounds down)
# * The remainder: % (gives the remainder of a division)

# %%
10 ** 2
# Out:
# 100

# %%
8 // 3
# Out:
# 2

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# <h1> To convert from one value to another: </h1>
#
# * int(X)
# * float(X)
# * str(X)
#
# Converts the value of X to the type specified by the function.

# %% [markdown]
# <h1> Order of Operations: PEMDAS and Left -> Right </h1>
#
# * Parentheses
# * Exponents
# * Multiplication
# * Division
# * Addition
# * Subtraction

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. The formula for computing the final amount if one is earning compound interest is given on Wikipedia as
#
#   Compounded Interest Formula:
#
#   P' = P(1+r/n) ^ nt
#
#   Write a Python program that assigns the principal amount of $10000 to variable P, assign to n the value 12, and assign to r the interest rate of 8%. Then have the program prompt the user for the number of years t that the money will be compounded for. Calculate and print the final amount after t years.

# %%
P = 10000
n = 12
r = 8/100

t = float(input("Tell me how old you are: "))

P * (1 + (r / n)) ** (n * t)
# Out:
# Tell me how old you are: 25
# 73401.75963739285

# %% [markdown]
# 2. You look at the clock and it is exactly 2pm. You set an alarm to go off in 51 hours. At what time does the alarm go off? (Hint: you could count on your fingers, but this is not what we’re after. If you are tempted to count on your fingers, change the 51 to 5100.)

# %%
hour = int(input("Tell me what time it is: "))
alarm = int(input("Tell me how many hours you want the alarm to go off: "))

(hour + alarm) % 24
# Out:
# Tell me what time it is: 2
# Tell me how many hours you want the alarm to go off: 51
# 5
