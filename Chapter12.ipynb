# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrainSD/Python-Learning-Notebooks/blob/main/Chapter12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 12: Modules

# %% [markdown]
# <h1> Random Numbers </h1>

# %% [markdown]
# In this way, we generate a list of random numbers and, by mixing them, we aim to make the result even more random.

# %%
import random

xs = list(range(1,13)) # Make list 1..12 (there are no duplicates)
rng = random.Random() # Make a random number generator
rng.shuffle(xs) # Shuffle the list
result = xs[:5] # Take the first five elements

# %% [markdown]
# <h1> Time </h1>

# %% [markdown]
# We are often interested in seeing how long a process takes. This is how we see it.

# %%
import time

def do_my_sum(xs):
  sum = 0
  for v in xs:
    sum += v
  return sum

sz = 10000000 # Lets have 10 million elements in the list
testdata = range(sz)

t0 = time.process_time()
my_result = do_my_sum(testdata)
t1 = time.process_time()
print("my_result = {0} (time taken = {1:.4f} seconds)".format(my_result, t1-t0))

t2 = time.process_time()
their_result = sum(testdata)
t3 = time.process_time()
print("their_result = {0} (time taken = {1:.4f} seconds)".format(their_result, t3-t2))
# Out:
# my_result = 49999995000000 (time taken = 0.7056 seconds)
# their_result = 49999995000000 (time taken = 0.2248 seconds)

# %% [markdown]
# <h1> Create your own modules </h1>

# %% [markdown]
# Something as simple as saving a function with a name and .py

# %% [markdown]
# <h1> Three types of imports </h1>
#
# * import x -> imports that library, and if you want to call a function, you use . with the library name in front
#
# * from x import y -> imports only the functions you are going to use and calls them to use them
#
# * from x import * -> imports all of them like the first one, but you won't have to use . to call them
#
# * Extra: import math as m -> This way you change the name you will use to call it.
